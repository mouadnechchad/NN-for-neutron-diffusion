# %%
# !pip install -r "/content/drive/MyDrive/Stage_PFE/DEPINN/requirements.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.4/890.4 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 61.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 46.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 83.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 kB 11.1 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement python==3.8 (from versions: none)
# ERROR: No matching distribution found for python==3.8

# %%
# %cd /content/drive/MyDrive/Stage_PFE/DEPINN/Code
# Out:
# /content/drive/MyDrive/Stage_PFE/DEPINN/Code

# %%
# !python main.py
# Out:
# Physics-Informed Neural Network (PINN) Training and Prediction
# --------------------------------------------------------------
# This script trains a PINN model using the provided data and
# performs predictions. It uses both Adam and L-BFGS optimizers
# to optimize the model's parameters.
# --------------------------------------------------------------
# Device Activated: cpu
# Device just before initializing PhysicsInformedNN: cpu
# Adam Iter: 1 Loss: 63956.83203125 Keff: 9.99999985098839
# Loss of boundary: 11.74804401397705 Loss of regions: 5.93934965133667 Loss of prior: 63939.14375
# Iter: 1, Time: 1.9470
# Adam Iter: 2 Loss: 63956.83203125 Keff: 9.99999985098839
# Loss of boundary: 11.74804401397705 Loss of regions: 5.93934965133667 Loss of prior: 63939.14375
# Iter: 2, Time: 1.3655
# Adam Iter: 3 Loss: 63956.83203125 Keff: 9.99999985098839
# Loss of boundary: 11.74804401397705 Loss of regions: 5.93934965133667 Loss of prior: 63939.14375
# Iter: 3, Time: 1.4236
# ...

# %%
# %cd /content/drive/MyDrive/Stage_PFE/DEPINN/data
# Out:
# /content/drive/MyDrive/Stage_PFE/DEPINN/data

# %%
import scipy.io

# Load the .mat file
data_path = '/content/drive/MyDrive/Stage_PFE/DEPINN/data'
data_pred = scipy.io.loadmat(f"{data_path}/U_Pred_Data.mat")

# View the keys in the loaded .mat file
print(data_pred.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'u_pred', 'v_pred'])
